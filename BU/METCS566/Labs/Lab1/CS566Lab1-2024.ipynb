# %% [markdown]
# ## Lab 1. Introduction to algorithms
#
# This is first Lab for CS 566. This problem was given in lecture.

# %% [markdown]
# ## Task 1. Solve the problem "Contains duplicate" from https://leetcode.com/problems/contains-duplicate/ using Python3
#
# Use the box below, to paste the working code. The format of the code should be identical to LeetCode platform. (4 points)

# %%
from typing import List

class Solution:
     def containsDuplicate(self, nums: List[int]) -> bool:
        hash_map = {}
        for number in nums:
            if number in hash_map:
                return True
            hash_map[number] = 1
        return False

# %% [markdown]
# ### Do not modify the testing code below. If you get message "Mistake in test case #", it means that you algorithm is incorrect.

# %%
#test_case_1
expected, nums = True, [1,2,3,1]
actual = Solution().containsDuplicate(nums)
assert expected==actual, "Mistake in test case 1"

#test_case_2
expected, nums = False, [1,2,3,4]
actual = Solution().containsDuplicate(nums)
assert expected==actual, "Mistake in test case 2"

#test_case_3
expected, nums = True, [1,1,1,3,3,4,3,2,4,2]
actual = Solution().containsDuplicate(nums)
assert expected==actual, "Mistake in test case 3"

# %% [markdown]
# ### Write analysis of the Memory Complexity and Time Complexity using Aymptotic Notation O. (1 point)
#
# Memory Analysis: O(n)
#
# Time Analysis: O(n)

# %% [markdown]
# ## Task 2. Theoretical problem.
#
# Suppose that for inputs of size *n* on a particular computer, insertion sort runs in $8*n^2$ steps and merge sort runs in $64*n*log(n)$ steps. For which values insertion sort beat merge sort? (5 points)
#
# Provide answer either in latex, or write on paper and embed screenshot into the colab notebook

# %% [markdown]
# Answer:
#
# $2 \le n \le 43$

# %% [markdown]
# ## Task 3. Theoretical problem.
#
# There are 4 algorithms with complexities:
# - $log(n)$
# - $\sqrt{n}$
# - $n^3$
# - $n$
#
# Order them in the order from fastest to slowest (5 points)

# %% [markdown]
# Answer:
#
# $log(n), \sqrt{n},n,n^3 $

# %%
import matplotlib.pyplot as plt
import numpy as np

# algos
n = np.linspace(1, 100, 400)
y1 = np.log(n)
y2 = np.sqrt(n)
y3 = n ** 3
y4 = n

#plot
fig = plt.figure()
plt.plot(n,y1, label='logn', color='g')
plt.plot(n,y2, label='sqrt(n)', color='r')
plt.plot(n,y3, label='n^3', color='b')
plt.plot(n,y4, label='n', color='y')
plt.ylim(0, 200)
plt.xlim(1, 100)
plt.legend()
plt.show()
